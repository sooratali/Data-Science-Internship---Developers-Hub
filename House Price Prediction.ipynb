# %%
# !pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.8/376.0 MB 5.6 MB/s eta 0:01:08
#    ---------------------------------------- 1.8/376.0 MB 4.6 MB/s eta 0:01:22
#    ---------------------------------------- 2.1/376.0 MB 3.9 MB/s eta 0:01:36
#    ---------------------------------------- 2.4/376.0 MB 3.1 MB/s eta 0:02:00
#    ---------------------------------------- 2.6/376.0 MB 2.8 MB/s eta 0:02:14
#    ---------------------------------------- 2.9/376.0 MB 2.6 MB/s eta 0:02:25
#    ---------------------------------------- 3.1/376.0 MB 2.3 MB/s eta 0:02:44
#    ---------------------------------------- 3.4/376.0 MB 2.1 MB/s eta 0:02:58
#    ---------------------------------------- 3.7/376.0 MB 2.0 MB/s eta 0:03:07
#    ---------------------------------------- 4.2/376.0 MB 1.9 MB/s eta 0:03:14
#    ---------------------------------------- 4.5/376.0 MB 1.9 MB/s eta 0:03:14
# ...

# %%
#import tensorflow as tf
#from tensorflow.keras.datasets import boston_housing
#from sklearn import preprocessing

# %%
(train_x,train_y),(test_x,test_y)=boston_housing.load_data()
# Out:
# ...
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 4us/step

# %%
print("Train Shape : ", train_x.shape)
print("Test Shape : ", test_x.shape)
print("Actual Train Output : ", train_y.shape)
print("Actual Test Output : ", test_x.shape)
# Out:
# Train Shape :  (404, 13)
# Test Shape :  (102, 13)
# Actual Train Output :  (404,)
# Actual Test Output :  (102, 13)

# %%
train_x[0]
# Out:
# array([  1.23247,   0.     ,   8.14   ,   0.     ,   0.538  ,   6.142  ,
#         91.7    ,   3.9769 ,   4.     , 307.     ,  21.     , 396.9    ,
#         18.72   ])

# %%
train_y[0]
# Out:
# 15.2

# %%
def normalize(X):
    mean = X.mean(axis=0)
    std = X.std(axis=0)
    return (X - mean) / std

train_x = normalize(train_x)
test_x = normalize(test_x)

# %%
train_x[0]
# Out:
# array([0.0024119 , 0.        , 0.01592969, 0.        , 0.00105285,
#        0.01201967, 0.17945359, 0.00778265, 0.00782786, 0.6007879 ,
#        0.04109624, 0.77671895, 0.03663436])

# %%
train_y[0]
# Out:
# 15.2

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *

def HousePricePredictionModel():
    #model = Sequential()
    #model.add(Dense(128,activation='relu',input_shape=(train_x[0].shape)))
    #model.add(Dense(64,activation='relu'))
    #model.add(Dense(32,activation='relu'))
    #model.add(Dense(1))
    #model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %%
import numpy as np
k=4
num_value_sample = len(train_x)
num_epchos = 100
all_scores = []

# %%
model = HousePricePredictionModel()
#history = model.fit(x=train_x, y=train_y, epochs=num_epchos, batch_size=1, verbose=1, validation_data=(test_x,test_y))
# Out:
# Epoch 1/100
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 303.9195 - mae: 13.4047 - val_loss: 66.8592 - val_mae: 5.9929
# Epoch 2/100
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 75.9351 - mae: 6.1213 - val_loss: 59.7127 - val_mae: 5.6243
# Epoch 3/100
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 57.6172 - mae: 5.1826 - val_loss: 60.8205 - val_mae: 5.6010
# Epoch 4/100
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 63.9292 - mae: 5.4738 - val_loss: 61.7018 - val_mae: 5.5836
# Epoch 5/100
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 58.7032 - mae: 5.2635 - val_loss: 56.8655 - val_mae: 5.4137
# Epoch 6/100
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 56.8348 - mae: 4.9352 - val_loss: 52.7599 - val_mae: 5.4074
# Epoch 7/100
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 58.0532 - mae: 5.4626 - val_loss: 53.3490 - val_mae: 5.2181
# Epoch 8/100
# ...

# %%
test_input = np.array([[8.65407330e-05, 0.00000000e+00, 1.13392175e-02, 1.12518247e-03, 
                        1.31897603e-02, 7.53763011e-02, 1.307768051e-02, 1.09241016e-02, 
                        4.89399752e-01, 4.41333705e-02, 8.67155186e-01, 1.75004108e-02, 
                        0.031]])
print("Actual Output : 21.1")
print("Predicted Output : ", model.predict(test_input)[0][0])
# Out:
# Actual Output : 21.1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step
# Predicted Output :  18.81555
